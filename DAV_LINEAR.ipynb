# %% [markdown]
# <a href="https://colab.research.google.com/github/Janmeshree/DAV-PRACS/blob/main/DAV_LINEAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Generate random data
np.random.seed(42)
X = 2 * np.random.rand(100, 1) # Independent variable
y = 4 + 3 * X + np.random.randn(100, 1) # Dependent variable with noise

# %%
# Train a simple linear regression model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Predictions
y_pred = model.predict(X)

# %%
# Plot the data and regression line
plt.scatter(X, y, color="blue", label="Data Points")
plt.plot(X, y_pred, color="red", label="Regression Line")
plt.xlabel("Independent Variable (X)")
plt.ylabel("Dependent Variable (y)")
plt.title("Simple Linear Regression")
plt.legend()
plt.show()

# %%
# Print model parameters
print(f"Intercept: {model.intercept_[0]}")
print(f"Coefficient: {model.coef_[0][0]}")
# Out:
# Intercept: 4.215096157546747
# Coefficient: 2.7701133864384837
